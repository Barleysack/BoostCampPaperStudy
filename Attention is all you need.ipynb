# %%
# !pip install torchtext==0.6.0
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.9.0+cu102)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (4.62.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.9 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.6.0) (3.7.4.3)
# Installing collected packages: sentencepiece, torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.10.0
#     Uninstalling torchtext-0.10.0:
#       Successfully uninstalled torchtext-0.10.0
# Successfully installed sentencepiece-0.1.96 torchtext-0.6.0

# %%
# %%capture
# !python -m spacy download en
# !python -m spacy download de

# %%
import spacy

spacy_en = spacy.load('en') # 영어 토큰화
spacy_de = spacy.load('de') # 독어 토큰화

# %%
tokenized = spacy_en.tokenizer("I am a graduate student.")

for i, token in enumerate(tokenized):
  print(i, token)
# Out:
# 0 I
# 1 am
# 2 a
# 3 graduate
# 4 student
# 5 .

# %%
#독어 토큰화 함수
def tokenize_de(text:str)->list:
  return [token.text for token in spacy_de.tokenizer(text)]

#영어 토큰화 함수
def tokenize_en(text:str)->list:
  return [token.text for token in spacy_en.tokenizer(text)]

# %%
from torchtext.data import Field, BucketIterator

#source : 독일어
SRC = Field(tokenize=tokenize_de, init_token="<sos>", eos_token="<eos>", lower=True, batch_first=True)
#Target : 영어
TRG = Field(tokenize=tokenize_en, init_token="<sos>", eos_token="<eos>", lower=True, batch_first=True)

# %%
#Multi30k 영어-독어 번역 dataset
from torchtext.datasets import Multi30k

train_dataset, valid_dataset, test_dataset= Multi30k.splits(exts=(".de",".en"), fields=(SRC, TRG))
# Out:
# downloading training.tar.gz
# training.tar.gz: 100%|██████████| 1.21M/1.21M [00:00<00:00, 1.61MB/s]
# downloading validation.tar.gz
# validation.tar.gz: 100%|██████████| 46.3k/46.3k [00:00<00:00, 249kB/s]
# downloading mmt_task1_test2016.tar.gz
# mmt_task1_test2016.tar.gz: 100%|██████████| 66.2k/66.2k [00:00<00:00, 239kB/s]

# %%
print(f"학습 데이터셋(training dataset) 크기: {len(train_dataset.examples)}개")
print(f"평가 데이터셋(validation dataset) 크기: {len(valid_dataset.examples)}개")
print(f"테스트 데이터셋(testing dataset) 크기: {len(test_dataset.examples)}개")
# Out:
# 학습 데이터셋(training dataset) 크기: 29000개
# 평가 데이터셋(validation dataset) 크기: 1014개
# 테스트 데이터셋(testing dataset) 크기: 1000개

# %%
#학습 데이터 중 하나를 선택해서 출력한다
print(vars(train_dataset.examples[30])['src'])
print(vars(train_dataset.examples[30])['trg'])
# Out:
# ['ein', 'mann', ',', 'der', 'mit', 'einer', 'tasse', 'kaffee', 'an', 'einem', 'urinal', 'steht', '.']
# ['a', 'man', 'standing', 'at', 'a', 'urinal', 'with', 'a', 'coffee', 'cup', '.']

# %%
#Field 객체에서 최소 2번 이상 나온 단어에 대해 영어와 독어의 work dict 생성한다.
SRC.build_vocab(train_dataset, min_freq=2)
TRG.build_vocab(train_dataset, min_freq=2)

print(f"len(SRC): {len(SRC.vocab)}")
print(f"len(TRG): {len(TRG.vocab)}")
# Out:
# {'freqs': Counter({'.': 28821, 'ein': 18850, 'einem': 13711, 'in': 11893, 'eine': 9908, ',': 8938, 'und': 8925, 'mit': 8843, 'auf': 8745, 'mann': 7805, 'einer': 6765, 'der': 4989, 'frau': 4186, 'die': 3948, 'zwei': 3873, 'einen': 3479, 'im': 3107, 'an': 3062, 'von': 2363, 'sich': 2273, 'dem': 2134, 'mädchen': 2121, 'junge': 2068, 'vor': 1936, 'zu': 1909, 'steht': 1778, 'männer': 1662, 'sitzt': 1624, 'hund': 1606, 'den': 1575, 'straße': 1412, 'während': 1397, 'gruppe': 1331, 'hält': 1310, 'spielt': 1307, 'das': 1261, 'hemd': 1202, 'personen': 1152, 'über': 1127, 'drei': 1078, 'eines': 1052, 'frauen': 993, 'blauen': 992, 'neben': 966, 'ist': 965, 'kind': 953, 'roten': 950, 'weißen': 950, 'stehen': 939, 'sitzen': 925, 'menschen': 924, 'am': 911, 'aus': 910, 'spielen': 910, 'durch': 895, 'bei': 885, 'geht': 857, 'trägt': 850, 'fährt': 835, 'wasser': 818, 'um': 795, 'kinder': 792, 'kleines': 772, 'person': 759, 'macht': 747, 'springt': 731, 'kleiner': 702, 'schwarzen': 702, 'entlang': 699, 'leute': 656, 'gehen': 613, 'etwas': 584, 'mehrere': 580, 'seinem': 578, 'großen': 565, 'oberteil': 552, 'jungen': 536, 'hand': 516, 'grünen': 505, 'läuft': 493, 'sind': 490, 'für': 480, 'hintergrund': 479, 'fahrrad': 478, 'freien': 475, 'jacke': 467, 'luft': 466, 'strand': 465, 'ball': 464, 'hat': 464, 'anderen': 461, 'schaut': 459, 'junger': 455, 'kleidung': 450, 'hinter': 433, 'sie': 429, 'nach': 426, 'andere': 412, 'gelben': 409, 'kleine': 403, 'gebäude': 397, 'vier': 396, 'hut': 395, 'tisch': 395, 'wird': 387, 'beim': 384, 'nähe': 383, 'essen': 377, 'kleinen': 376, 'schwarzer': 371, 'menschenmenge': 371, 'kamera': 363, 'vorbei': 356, 'paar': 356, 'gras': 355, 'hoch': 355, 't-shirt': 354, 'hunde': 352, 'boden': 349, 'schnee': 346, 'rennt': 339, 'ihre': 337, 'unter': 329, 'ihren': 321, 'kleid': 313, 'gitarre': 303, 'älterer': 299, 'sein': 292, 'zusammen': 292, 'draußen': 292, 'ihr': 290, 'feld': 288, 'bühne': 286, 'fahren': 285, 'brille': 280, 'seine': 277, 'herum': 276, 'rennen': 274, 'gehweg': 272, 'sehen': 272, 'kopf': 272, 'er': 271, 'blickt': 266, 'seinen': 266, 'dabei': 266, 'foto': 266, 'weißer': 265, 'des': 263, 'stadt': 259, 'park': 257, 'braunen': 257, 'hinunter': 257, 'liegt': 254, 'versucht': 253, 'laufen': 253, 'arbeitet': 250, 'jeans': 250, 'als': 245, 'bank': 244, 'tragen': 241, 'baby': 240, 'wie': 238, 'dame': 238, 'machen': 235, 'lächelt': 234, 'große': 234, 'schauen': 233, 'brauner': 232, 'ihrem': 229, 'schwarz': 224, 'ältere': 224, 'orangefarbenen': 223, 'ihm': 222, 'junges': 220, 'bürgersteig': 216, 'arbeiten': 215, 'hose': 215, 'zeigt': 214, 'sieht': 213, 'spricht': 211, 'liest': 210, 'unterhalten': 209, 'skateboard': 208, 'halten': 205, 'haaren': 204, 'wand': 204, 'weg': 202, 'viele': 197, 'sonnenbrille': 195, 'zum': 194, 'boot': 192, 'pferd': 192, 'gekleidete': 191, 'seiner': 190, 'hosen': 188, 'tag': 188, 'rosa': 188, 'helm': 185, 'weißem': 184, 'grauen': 183, 'singt': 182, 'ihnen': 181, 'gesicht': 180, 'blauem': 180, '„': 178, 'bild': 177, 'mantel': 176, 'auto': 175, 'posiert': 174, 'felsen': 173, 'fußball': 173, 'darauf': 173, 'fünf': 172, 'klettert': 171, 'führt': 170, 'shorts': 170, 'befindet': 169, 'einige': 168, 'sand': 164, 'mikrofon': 163, 'baum': 162, 'schwarzem': 161, 'sehr': 161, 'wirft': 161, 'blauer': 161, 'gekleideter': 159, 'es': 157, 'weiß': 157, 'band': 157, '“': 156, 'blau': 155, 'meer': 155, 'oder': 154, 'rotem': 152, 'restaurant': 151, 'isst': 151, 'wald': 151, 'schwarze': 150, 'männern': 150, 'arbeiter': 150, 'kindern': 149, 'anderer': 149, 'wiese': 149, 'raum': 149, 'fenster': 148, 'wartet': 147, 'roter': 147, 'langen': 147, 'pullover': 147, 'weiße': 146, 'ins': 145, 'anzug': 144, 'bluse': 141, 'posieren': 141, 'gestreiften': 141, 'motorrad': 140, 'tanzen': 139, 'springen': 139, 'haar': 139, 'werden': 139, 'trikot': 139, 'voller': 137, 'oberkörper': 137, 'bereitet': 136, 'stuhl': 134, 'spieler': 133, 'betrachtet': 132, 'rot': 132, 'alter': 131, 'hügel': 131, 'blonde': 130, 'schild': 130, 'zwischen' ...
# {'freqs': Counter({'a': 49165, '.': 27623, 'in': 14886, 'the': 10955, 'on': 8035, 'man': 7781, 'is': 7525, 'and': 7379, 'of': 6871, 'with': 6179, 'woman': 3973, ',': 3963, 'two': 3886, 'are': 3717, 'to': 3128, 'people': 3122, 'at': 2927, 'an': 2861, 'wearing': 2623, 'shirt': 2324, 'young': 2280, 'white': 2238, 'black': 2019, 'his': 1969, 'while': 1947, 'blue': 1880, 'men': 1759, 'red': 1755, 'sitting': 1743, 'girl': 1723, 'boy': 1687, 'dog': 1675, 'standing': 1614, 'playing': 1584, 'group': 1553, 'street': 1449, 'down': 1404, 'walking': 1378, '-': 1343, 'front': 1274, 'her': 1263, 'holding': 1238, 'one': 1092, 'water': 1064, 'three': 1057, 'by': 1046, 'women': 988, 'up': 938, 'green': 926, 'little': 916, 'for': 906, 'child': 894, 'looking': 894, 'outside': 871, 'as': 851, 'large': 843, 'through': 813, 'brown': 795, 'yellow': 785, 'children': 768, 'person': 752, 'from': 728, 'their': 725, 'hat': 724, 'ball': 723, 'into': 711, 'small': 671, 'next': 664, 'other': 660, 'dressed': 643, 'some': 622, 'out': 620, 'over': 615, 'building': 602, 'riding': 584, 'running': 581, 'near': 571, 'jacket': 565, 'another': 562, 'around': 561, 'sidewalk': 534, 'field': 532, 'orange': 526, 'crowd': 522, 'beach': 520, 'stands': 497, 'pink': 494, 'sits': 492, 'jumping': 491, 'behind': 489, 'table': 480, 'snow': 478, 'grass': 468, 'hair': 466, 'background': 460, 'bike': 449, 'stand': 447, 'city': 445, "'s": 444, 'air': 442, 'girls': 440, 'player': 429, 'asian': 422, 'looks': 420, 'wall': 417, 'top': 416, 'four': 405, 'off': 405, 'several': 404, 'that': 404, 'dogs': 404, 'older': 401, 'camera': 395, 'dress': 390, 'park': 388, 'talking': 382, 'lady': 380, 'something': 380, 'blond': 375, 'soccer': 375, 'along': 370, 'walks': 369, 'guitar': 368, 'boys': 364, 'play': 363, 'together': 361, 'working': 360, 'food': 357, 'gray': 354, 'smiling': 353, 'picture': 340, 'has': 339, 'game': 339, 'plays': 331, 'car': 327, 'hand': 326, 'holds': 322, 'it': 319, 'road': 314, 'him': 312, 'bench': 310, 'old': 309, 'glasses': 306, 'pants': 306, 'shorts': 304, 'stage': 303, 'sit': 301, 'carrying': 300, 'walk': 300, 'couple': 299, 'baby': 299, 'them': 290, 'side': 289, 'bicycle': 288, 'face': 287, 'tree': 286, '"': 280, 'male': 279, 'pool': 276, 'race': 275, 'taking': 275, 'long': 275, 'rock': 274, 'middle': 272, 'each': 272, 'doing': 267, 'dirt': 263, 'watching': 261, 'head': 261, 'across': 261, 'guy': 260, 'jeans': 259, 'there': 259, 'dark': 258, 'area': 258, 'jumps': 250, 'boat': 249, 'hands': 248, 'back': 245, 'female': 245, 'day': 243, 'ground': 243, 'performing': 241, 'room': 241, 'baseball': 238, 'who': 237, 'eating': 236, 'being': 233, 'football': 229, 'coat': 228, 'striped': 227, 'using': 227, 'kids': 225, 'suit': 225, 'under': 224, 'horse': 224, 'watch': 223, 'band': 223, 'many': 222, 'mouth': 221, 'purple': 221, 'he': 220, 'sign': 219, 'store': 217, 't': 216, 'this': 216, 'haired': 215, 'sand': 214, 'runs': 212, 'tennis': 212, 'players': 209, 'look': 209, 'sunglasses': 208, 'construction': 208, 'reading': 206, 'clothing': 203, 'microphone': 202, 'mountain': 200, 'toy': 199, 'covered': 199, 'ocean': 198, 'basketball': 198, 'during': 197, 'its': 197, 'workers': 197, 'watches': 194, 'climbing': 193, 'uniform': 192, 'past': 191, 'elderly': 190, 'restaurant': 188, 'helmet': 188, 'against': 187, 'train': 185, 'team': 185, 'window': 183, 'dancing': 183, 'rides': 181, 'shirts': 179, 'they': 178, 'chair': 178, 'work': 178, 'about': 177, 'wooden': 175, 'be': 175, 'posing': 174, 'trees': 174, 'five': 173, 'having': 173, 'outdoor': 173, 'waiting': 171, 'all': 169, 'swimming': 169, 'getting': 168, 'or': 167, 'floor': 166, 'trying': 165, 'ice': 164, 'very': 164, 'skateboard': 163, 'colorful': 163, 'high': 161, 'bag': 161, 'busy': 160, 'singing': 159, 'fence': 159, 'jump': 158, 'cart': 153, 'line': 152, 'laying': 150, 'market': 149, 'hill': 149, 'truck': 149, 'bright': 147, 'book': 147, 'hats': 146, 'tan': 146, 'ride': 146, 'inside': 146, 'others': 145, 'kitchen': 145, 'cap': 14 ...

# %%
print(TRG.vocab.stoi["abcabc"]) # 없는 단어: 0
print(TRG.vocab.stoi[TRG.pad_token]) # 패딩(padding): 1
print(TRG.vocab.stoi["<sos>"]) # <sos>: 2
print(TRG.vocab.stoi["<eos>"]) # <eos>: 3
print(TRG.vocab.stoi["hello"])
print(TRG.vocab.stoi["world"])
# Out:
# 0
# 1
# 2
# 3
# 4112
# 1752

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

BATCH_SIZE = 128

# %%
# 일반적인 데이터 로더(data loader)의 iterator와 유사하게 사용 가능

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_dataset, valid_dataset, test_dataset),
    batch_size=BATCH_SIZE,
    device=device)

# %%
for i, batch in enumerate(train_iterator):
  src = batch.src
  trg = batch.trg

  print(src.shape)
  
  # 현재 배치에 있는 하나의 문장에 포함된 정보 출력
  for i in range(src.shape[1]):
    print(i, src[0][i].item())  # 여기에서는 [Seq_num, Seq_len]

  break # 첫 번째 배치만 확인
# Out:
# torch.Size([128, 27])
# 0 2
# 1 5
# 2 13
# 3 11
# 4 50
# 5 606
# 6 9
# 7 202
# 8 40
# 9 10
# 10 203
# 11 198
# 12 9
# 13 15
# 14 217
# 15 4
# 16 3
# 17 1
# 18 1
# 19 1
# 20 1
# 21 1
# 22 1
# 23 1
# 24 1
# 25 1
# 26 1

# %%
import torch.nn as nn

class MultiHeadAttentionLayer(nn.Module):
  def __init__(self, hidden_dim, n_heads, dropout_ratio, device):
    super.__init__()

    assert hidden_dim % n_hreads == 0

    self.hidden_dim = hidden_dim  #임베딩 벡터 차원
    self.n_heads=n_heads  #헤드 수
    self.head_dim = hidden_dim // n_heads #각 헤드에서의 차원

    self.fc_q = nn.Linear(hidden_dim, hidden_dim) # Query 값에 적용될 FC 레이어
    self.fc_k = nn.Linear(hidden_dim, hidden_dim) # Key 값에 적용될 FC 레이어
    self.fc_v = nn.Linear(hidden_dim, hidden_dim) # Value 값에 적용될 FC 레이어

    self.fc_o = nn.Linear(hidden_dim, hidden_dim)

    self.dropout = nn.Dropout(dropout_ratio)

    self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)

    def forward(self, query, key, value, mask = None):
      batch_size = query.shape[0]

      Q = self.fc_q(query)
      K = self.fc_k(query)
      V = self.fc_v(query)

      Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0,2,1,3)
      K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0,2,1,3)
      V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0,2,1,3)

      energy = torch.matmul(Q, K.permute(0,1,3,2)) / self.scale

      if mask is not None:
        energy = energy.masked_fill(mask==0, -1e10)

      attention = torch.softmax(energy,dim=-1)

      x = torch.matmul(self.dropdout(attention), V)

      x = x.permute(0,2,1,3).contiguous()

      x = x.view(batch_size, -1, self.hidden_dim)

      x = self.fc_o(x)

      return x, attention
